# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
years=[1960,1970,1980,1990,2000,2010,2020]
iranpop=[21.19,28.51,38.67,56.23,66.13,74.75,80.29]

# %%
plt.figure(figsize=(6,4),dpi=100)
plt.plot(years,iranpop)
plt.grid('True')
plt.xlabel('Year')
plt.ylabel('Population')
plt.yticks([21.19,28.51,38.67,56.23,66.13,74.75,80.29],labels=['21m','28m','38m','56m','66m','74m','80m'])
# Out:
# ([<matplotlib.axis.YTick at 0x79982dd5aab0>,
# ...
#  [Text(0, 21.19, '21m'),
#   Text(0, 28.51, '28m'),
#   Text(0, 38.67, '38m'),
#   Text(0, 56.23, '56m'),
#   Text(0, 66.13, '66m'),
#   Text(0, 74.75, '74m'),
#   Text(0, 80.29, '80m')])

# %%
plt.scatter(years,iranpop)

# %%
cityName = ['Tehran','Mashhad','Isfahan','Karaj','Tabriz','Shiraz']
cityPop = [7153309,2307177,1547164,1448075,1424641,1249942]

# %%
plt.figure(figsize=(5,3))
plt.hist(cityPop)
# Out:
# (array([4., 1., 0., 0., 0., 0., 0., 0., 0., 1.]),
#  array([1249942. , 1840278.7, 2430615.4, 3020952.1, 3611288.8, 4201625.5,
#         4791962.2, 5382298.9, 5972635.6, 6562972.3, 7153309. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(cityPop,bins=1)
# Out:
# (array([6.]), array([1249942., 7153309.]), <BarContainer object of 1 artists>)

# %%
plt.hist(cityPop,bins='auto')
# Out:
# (array([4., 1., 0., 0., 0., 0., 0., 1.]),
#  array([1249942.   , 1987862.875, 2725783.75 , 3463704.625, 4201625.5  ,
#         4939546.375, 5677467.25 , 6415388.125, 7153309.   ]),
#  <BarContainer object of 8 artists>)

# %%
plt.hist(cityPop,bins=2)
# Out:
# (array([5., 1.]),
#  array([1249942. , 4201625.5, 7153309. ]),
#  <BarContainer object of 2 artists>)

# %%
sb.histplot(x=cityName,y=cityPop)
# Out:
# <Axes: >

# %%
plt.pie(cityPop,labels=cityName)
# Out:
# ([<matplotlib.patches.Wedge at 0x799806632cc0>,
# ...
#  [Text(0.09395048803993974, 1.0959805225445647, 'Tehran'),
#   Text(-1.0482276359382692, -0.3334948624121029, 'Mashhad'),
#   Text(-0.4907783951606389, -0.9844473408179577, 'Isfahan'),
#   Text(0.1746486304819908, -1.0860468939556733, 'Karaj'),
#   Text(0.7545580220372188, -0.8004012689765554, 'Tabriz'),
#   Text(1.0631610423416065, -0.28229168965293533, 'Shiraz')])

# %%
import seaborn as sb

# %%
randomData=np.random.normal(0,1,1000000)

# %%
plt.hist(randomData,bins=30,color='skyblue',edgecolor='black')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Random Number Histogram')
#plt.show()
# Out:
# Text(0.5, 1.0, 'Random Number Histogram')

# %%
sb.histplot(randomData, bins=30, kde=True, color='lightgreen', edgecolor='red')
# Out:
# <Axes: ylabel='Count'>

# %%
color=np.arange(6)
popSize=np.array([7153309,2307177,1547164,1448075,1424641,1249942])/10000
plt.margins(.1)
plt .scatter(np.arange(6),cityPop,s=popSize,alpha=1,c=color)
plt.xticks([0,1,2,3,4,5],['Tehran','Mashhad','Isfahan','Karaj','Tabriz','Shiraz'])
plt.yticks([1000000,2000000,3000000,4000000,5000000,6000000,7000000],['1m','2m','3m','4m','5m','6m','7m'])
plt.text(0.3,7153309,'Tehran')
#plt.arrow(0,7153309,1,1)
# Out:
# Text(0.3, 7153309, 'Tehran')
