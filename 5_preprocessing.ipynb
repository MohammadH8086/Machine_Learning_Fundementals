# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import preprocessing

# %%
countries=pd.read_csv('country.csv',header=1)
countries
# Out:
#      1  CountryName CountryCode Population growth Total population  \
# 0    2       Brazil         BRA       0.817555711        207652865
# 1    3  Switzerland         CHE       1.077221168          8372098
# 2    4      Germany         DEU       1.193866758         82667685
# 3    5      Denmark         DNK       0.834637611                ?
# 4    6        Spain         ESP      -0.008048086         46443959
# 5    7       France         FRA       0.407491036         66896109
# 6    8        Japan         JPN      -0.115284177        126994511
# 7    9       Greece         GRC      -0.687542545         10746740
# 8   10         Iran         IRN         1.1487886         80277428
# 9   11       Kuwait         KWT       2.924206194          4052584
# 10  12      Morocco         MAR                 ?         35276786
# 11  13      Nigeria         NGA       2.619033526        185989640
# 12  14        Qatar         QAT       3.495069918          2569804
# ...

# %%
countries.rename(columns={'CountryName':'Name','CountryCode':'Code','Population growth':'Pop_growth',
                          	'Total population':'Pop',	'Area (sq. km)':'Area'},inplace=True)

# %%
countries
# Out:
#      1         Name Code    Pop_growth         Pop         Area
# 0    2       Brazil  BRA   0.817555711   207652865      8358140
# 1    3  Switzerland  CHE   1.077221168     8372098        39516
# 2    4      Germany  DEU   1.193866758    82667685       348900
# 3    5      Denmark  DNK   0.834637611           ?        42262
# 4    6        Spain  ESP  -0.008048086    46443959       500210
# 5    7       France  FRA   0.407491036    66896109       547557
# 6    8        Japan  JPN  -0.115284177   126994511       364560
# 7    9       Greece  GRC  -0.687542545    10746740       128900
# 8   10         Iran  IRN     1.1487886    80277428      1628760
# 9   11       Kuwait  KWT   2.924206194     4052584            ?
# 10  12      Morocco  MAR             ?    35276786       446300
# 11  13      Nigeria  NGA   2.619033526   185989640       910770
# 12  14        Qatar  QAT   3.495069918     2569804        11610
# 13  15       Sweden  SWE             ?     9903122       407310
# ...

# %%
countries.drop(['1','Code'],axis=1,inplace=True)

# %%
countries
# Out:
#            Name    Pop_growth         Pop         Area
# 0        Brazil   0.817555711   207652865      8358140
# 1   Switzerland   1.077221168     8372098        39516
# 2       Germany   1.193866758    82667685       348900
# 3       Denmark   0.834637611           ?        42262
# 4         Spain  -0.008048086    46443959       500210
# 5        France   0.407491036    66896109       547557
# 6         Japan  -0.115284177   126994511       364560
# 7        Greece  -0.687542545    10746740       128900
# 8          Iran     1.1487886    80277428      1628760
# 9        Kuwait   2.924206194     4052584            ?
# 10      Morocco             ?    35276786       446300
# 11      Nigeria   2.619033526   185989640       910770
# 12        Qatar   3.495069918     2569804        11610
# 13       Sweden             ?     9903122       407310
# 14        India   1.148214693  1324171354      2973190
# 15        World    1.18167997  7442135578  129733172.7

# %%
countries.rename(index=countries.Name,inplace=True)

# %%
countries
# Out:
#                     Name    Pop_growth         Pop         Area
# Brazil            Brazil   0.817555711   207652865      8358140
# Switzerland  Switzerland   1.077221168     8372098        39516
# Germany          Germany   1.193866758    82667685       348900
# Denmark          Denmark   0.834637611           ?        42262
# Spain              Spain  -0.008048086    46443959       500210
# France            France   0.407491036    66896109       547557
# Japan              Japan  -0.115284177   126994511       364560
# Greece            Greece  -0.687542545    10746740       128900
# Iran                Iran     1.1487886    80277428      1628760
# Kuwait            Kuwait   2.924206194     4052584            ?
# Morocco          Morocco             ?    35276786       446300
# Nigeria          Nigeria   2.619033526   185989640       910770
# Qatar              Qatar   3.495069918     2569804        11610
# Sweden            Sweden             ?     9903122       407310
# ...

# %%
countries.drop('Name',axis=1,inplace=True)

# %%
countries
# Out:
#                Pop_growth         Pop         Area
# Brazil        0.817555711   207652865      8358140
# Switzerland   1.077221168     8372098        39516
# Germany       1.193866758    82667685       348900
# Denmark       0.834637611           ?        42262
# Spain        -0.008048086    46443959       500210
# France        0.407491036    66896109       547557
# Japan        -0.115284177   126994511       364560
# Greece       -0.687542545    10746740       128900
# Iran            1.1487886    80277428      1628760
# Kuwait        2.924206194     4052584            ?
# Morocco                 ?    35276786       446300
# Nigeria       2.619033526   185989640       910770
# Qatar         3.495069918     2569804        11610
# Sweden                  ?     9903122       407310
# India         1.148214693  1324171354      2973190
# World          1.18167997  7442135578  129733172.7

# %%
countries.head()
# Out:
#                Pop_growth        Pop     Area
# Brazil        0.817555711  207652865  8358140
# Switzerland   1.077221168    8372098    39516
# Germany       1.193866758   82667685   348900
# Denmark       0.834637611          ?    42262
# Spain        -0.008048086   46443959   500210

# %%
countries.tail()
# Out:
#           Pop_growth         Pop         Area
# Nigeria  2.619033526   185989640       910770
# Qatar    3.495069918     2569804        11610
# Sweden             ?     9903122       407310
# India    1.148214693  1324171354      2973190
# World     1.18167997  7442135578  129733172.7

# %%
countries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16 entries, Brazil to World
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Pop_growth  16 non-null     object
#  1   Pop         16 non-null     object
#  2   Area        16 non-null     object
# dtypes: object(3)
# memory usage: 512.0+ bytes

# %%
countries.describe()
# Out:
#        Pop_growth        Pop     Area
# count          16         16       16
# unique         15         16       16
# top             ?  207652865  8358140
# freq            2          1        1

# %%
countries.replace('?',0,inplace=True)

# %%
countries
# Out:
#                Pop_growth         Pop         Area
# Brazil        0.817555711   207652865      8358140
# Switzerland   1.077221168     8372098        39516
# Germany       1.193866758    82667685       348900
# Denmark       0.834637611           0        42262
# Spain        -0.008048086    46443959       500210
# France        0.407491036    66896109       547557
# Japan        -0.115284177   126994511       364560
# Greece       -0.687542545    10746740       128900
# Iran            1.1487886    80277428      1628760
# Kuwait        2.924206194     4052584            0
# Morocco                 0    35276786       446300
# Nigeria       2.619033526   185989640       910770
# Qatar         3.495069918     2569804        11610
# Sweden                  0     9903122       407310
# India         1.148214693  1324171354      2973190
# World          1.18167997  7442135578  129733172.7

# %%
countries.describe(include='all')
# Out:
#         Pop_growth        Pop     Area
# count           16         16       16
# unique          15         16       16
# top              0  207652865  8358140
# freq             2          1        1

# %%
countries.dtypes
# Out:
# Pop_growth    object
# Pop           object
# Area          object
# dtype: object

# %%
type(countries)
# Out:
# pandas.core.frame.DataFrame

# %%
countries.Pop_growth= countries['Pop_growth'].astype(float)

# %%
countries['Pop']=countries['Pop'].astype(int)

# %%
countries['Area']=countries['Area'].astype(complex)

# %%
countries
# Out:
#              Pop_growth         Pop  \
# Brazil         0.817556   207652865
# Switzerland    1.077221     8372098
# Germany        1.193867    82667685
# Denmark        0.834638           0
# Spain         -0.008048    46443959
# France         0.407491    66896109
# Japan         -0.115284   126994511
# Greece        -0.687543    10746740
# Iran           1.148789    80277428
# Kuwait         2.924206     4052584
# Morocco        0.000000    35276786
# Nigeria        2.619034   185989640
# Qatar          3.495070     2569804
# Sweden         0.000000     9903122
# India          1.148215  1324171354
# World          1.181680  7442135578
#
#                                                        Area
# Brazil       8.358140e+06+0.000000e+                    00j
# Switzerland  3.951600e+04+0.000000e+                    00j
# Germany      3.489000e+05+0.000000e+                    00j
# Denmark      4.226200e+04+0.000000e+                    00j
# ...

# %%
countries['Area']=countries['Area'].astype(int)
# Out:
# /home/mohammad-hossein-abedi/Documents/Code/Machine_learning_Puyan_Rajiyan/lib/python3.12/site-packages/pandas/core/dtypes/astype.py:133: ComplexWarning: Casting complex values to real discards the imaginary part
#   return arr.astype(dtype, copy=True)

# %%
countries.describe()
# Out:
#        Pop_growth           Pop          Area
# count   16.000000  1.600000e+01  1.600000e+01
# mean     1.002306  6.021344e+08  9.152572e+06
# std      1.160152  1.852081e+09  3.222189e+07
# min     -0.687543  0.000000e+00  0.000000e+00
# 25%      0.000000  9.520366e+06  1.072405e+05
# 50%      0.955929  5.667003e+07  4.268050e+05
# 75%      1.184727  1.417433e+08  1.090268e+06
# max      3.495070  7.442136e+09  1.297332e+08

# %%
countries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16 entries, Brazil to World
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Pop_growth  16 non-null     float64
#  1   Pop         16 non-null     int64
#  2   Area        16 non-null     int64
# dtypes: float64(1), int64(2)
# memory usage: 512.0+ bytes

# %%
countries[countries['Pop']==countries['Pop'].max()]
# Out:
#        Pop_growth         Pop       Area
# World     1.18168  7442135578  129733172

# %%
countries['Pop'].max()
# Out:
# 7442135578

# %%
countries.drop('World',inplace=True,axis=0)

# %%
countries
# Out:
#              Pop_growth         Pop     Area
# Brazil         0.817556   207652865  8358140
# Switzerland    1.077221     8372098    39516
# Germany        1.193867    82667685   348900
# Denmark        0.834638           0    42262
# Spain         -0.008048    46443959   500210
# France         0.407491    66896109   547557
# Japan         -0.115284   126994511   364560
# Greece        -0.687543    10746740   128900
# Iran           1.148789    80277428  1628760
# Kuwait         2.924206     4052584        0
# Morocco        0.000000    35276786   446300
# Nigeria        2.619034   185989640   910770
# Qatar          3.495070     2569804    11610
# Sweden         0.000000     9903122   407310
# India          1.148215  1324171354  2973190

# %%
countries.describe()
# Out:
#        Pop_growth           Pop          Area
# count   15.000000  1.500000e+01  1.500000e+01
# mean     0.990347  1.461343e+08  1.113866e+06
# std      1.199851  3.325660e+08  2.150749e+06
# min     -0.687543  0.000000e+00  0.000000e+00
# 25%      0.000000  9.137610e+06  8.558100e+04
# 50%      0.834638  4.644396e+07  4.073100e+05
# 75%      1.171328  1.048311e+08  7.291635e+05
# max      3.495070  1.324171e+09  8.358140e+06

# %%
countries[countries['Pop']==countries['Pop'].max()]
# Out:
#        Pop_growth         Pop     Area
# India    1.148215  1324171354  2973190

# %%
countries.isnull()
# Out:
#              Pop_growth    Pop   Area
# Brazil            False  False  False
# Switzerland       False  False  False
# Germany           False  False  False
# Denmark           False  False  False
# Spain             False  False  False
# France            False  False  False
# Japan             False  False  False
# Greece            False  False  False
# Iran              False  False  False
# Kuwait            False  False  False
# Morocco           False  False  False
# Nigeria           False  False  False
# Qatar             False  False  False
# Sweden            False  False  False
# India             False  False  False

# %%
countries.isnull().sum()
# Out:
# Pop_growth    0
# Pop           0
# Area          0
# dtype: int64

# %%
(countries[['Pop','Area','Pop_growth']]==0).sum()
# Out:
# Pop           1
# Area          1
# Pop_growth    2
# dtype: int64

# %%
countries_copy=countries.copy(deep=True)

# %%
countries_copy
# Out:
#              Pop_growth         Pop     Area
# Brazil         0.817556   207652865  8358140
# Switzerland    1.077221     8372098    39516
# Germany        1.193867    82667685   348900
# Denmark        0.834638           0    42262
# Spain         -0.008048    46443959   500210
# France         0.407491    66896109   547557
# Japan         -0.115284   126994511   364560
# Greece        -0.687543    10746740   128900
# Iran           1.148789    80277428  1628760
# Kuwait         2.924206     4052584        0
# Morocco        0.000000    35276786   446300
# Nigeria        2.619034   185989640   910770
# Qatar          3.495070     2569804    11610
# Sweden         0.000000     9903122   407310
# India          1.148215  1324171354  2973190

# %%
countries_copy[countries_copy['Pop']==0].index
# Out:
# Index(['Denmark'], dtype='object')

# %%
countries_copy[countries_copy['Pop']==0]
# Out:
#          Pop_growth  Pop   Area
# Denmark    0.834638    0  42262

# %%
countries_copy.drop(countries_copy[countries_copy['Pop']==0].index,axis=0,inplace=True)

# %%
countries_copy[countries_copy['Pop']==0].index
# Out:
# Index([], dtype='object')

# %%
countries_copy[countries_copy['Area']==0].index
# Out:
# Index(['Kuwait'], dtype='object')

# %%
countries_copy[countries_copy['Pop_growth']==0].index
# Out:
# Index(['Morocco', 'Sweden'], dtype='object')

# %%
countries_copy.drop(countries_copy[countries_copy['Area']==0].index,axis=0,inplace=True)

# %%
countries_copy.drop(countries_copy[countries_copy['Pop_growth']==0].index,axis=0,inplace=True)

# %%
countries_copy
# Out:
#              Pop_growth         Pop     Area
# Brazil         0.817556   207652865  8358140
# Switzerland    1.077221     8372098    39516
# Germany        1.193867    82667685   348900
# Spain         -0.008048    46443959   500210
# France         0.407491    66896109   547557
# Japan         -0.115284   126994511   364560
# Greece        -0.687543    10746740   128900
# Iran           1.148789    80277428  1628760
# Nigeria        2.619034   185989640   910770
# Qatar          3.495070     2569804    11610
# India          1.148215  1324171354  2973190

# %%
countries
# Out:
#              Pop_growth         Pop     Area
# Brazil         0.817556   207652865  8358140
# Switzerland    1.077221     8372098    39516
# Germany        1.193867    82667685   348900
# Denmark        0.834638           0    42262
# Spain         -0.008048    46443959   500210
# France         0.407491    66896109   547557
# Japan         -0.115284   126994511   364560
# Greece        -0.687543    10746740   128900
# Iran           1.148789    80277428  1628760
# Kuwait         2.924206     4052584        0
# Morocco        0.000000    35276786   446300
# Nigeria        2.619034   185989640   910770
# Qatar          3.495070     2569804    11610
# Sweden         0.000000     9903122   407310
# India          1.148215  1324171354  2973190

# %%
countries['Pop_growth'].replace(0,method='bfill')
# Out:
# /tmp/ipykernel_37131/1618553936.py:1: FutureWarning: The 'method' keyword in Series.replace is deprecated and will be removed in a future version.
#   countries['Pop_growth'].replace(0,method='bfill')
# Brazil         0.817556
# Switzerland    1.077221
# Germany        1.193867
# Denmark        0.834638
# Spain         -0.008048
# France         0.407491
# Japan         -0.115284
# Greece        -0.687543
# Iran           1.148789
# Kuwait         2.924206
# Morocco        2.619034
# Nigeria        2.619034
# Qatar          3.495070
# Sweden         1.148215
# India          1.148215
# Name: Pop_growth, dtype: float64

# %%
countries
# Out:
#              Pop_growth         Pop     Area
# Brazil         0.817556   207652865  8358140
# Switzerland    1.077221     8372098    39516
# Germany        1.193867    82667685   348900
# Denmark        0.834638           0    42262
# Spain         -0.008048    46443959   500210
# France         0.407491    66896109   547557
# Japan         -0.115284   126994511   364560
# Greece        -0.687543    10746740   128900
# Iran           1.148789    80277428  1628760
# Kuwait         2.924206     4052584        0
# Morocco        0.000000    35276786   446300
# Nigeria        2.619034   185989640   910770
# Qatar          3.495070     2569804    11610
# Sweden         0.000000     9903122   407310
# India          1.148215  1324171354  2973190

# %%
from sklearn.impute import SimpleImputer

# %%
simple_imputer=SimpleImputer(missing_values=0,strategy='mean')

# %%
simple_imputer.fit(countries)
# Out:
# SimpleImputer(missing_values=0)

# %%
countries_copy2=simple_imputer.transform(countries)

# %%
countries_copy2
# Out:
# array([[ 8.17555711e-01,  2.07652865e+08,  8.35814000e+06],
#        [ 1.07722117e+00,  8.37209800e+06,  3.95160000e+04],
#        [ 1.19386676e+00,  8.26676850e+07,  3.48900000e+05],
#        [ 8.34637611e-01,  1.56572478e+08,  4.22620000e+04],
#        [-8.04808600e-03,  4.64439590e+07,  5.00210000e+05],
#        [ 4.07491036e-01,  6.68961090e+07,  5.47557000e+05],
#        [-1.15284177e-01,  1.26994511e+08,  3.64560000e+05],
#        [-6.87542545e-01,  1.07467400e+07,  1.28900000e+05],
#        [ 1.14878860e+00,  8.02774280e+07,  1.62876000e+06],
#        [ 2.92420619e+00,  4.05258400e+06,  1.19342750e+06],
#        [ 1.14270849e+00,  3.52767860e+07,  4.46300000e+05],
#        [ 2.61903353e+00,  1.85989640e+08,  9.10770000e+05],
#        [ 3.49506992e+00,  2.56980400e+06,  1.16100000e+04],
#        [ 1.14270849e+00,  9.90312200e+06,  4.07310000e+05],
#        [ 1.14821469e+00,  1.32417135e+09,  2.97319000e+06]])

# %%
countries_copy2= pd.DataFrame(countries_copy2,columns=countries.columns,index=countries.index)

# %%
countries
# Out:
#              Pop_growth         Pop     Area
# Brazil         0.817556   207652865  8358140
# Switzerland    1.077221     8372098    39516
# Germany        1.193867    82667685   348900
# Denmark        0.834638           0    42262
# Spain         -0.008048    46443959   500210
# France         0.407491    66896109   547557
# Japan         -0.115284   126994511   364560
# Greece        -0.687543    10746740   128900
# Iran           1.148789    80277428  1628760
# Kuwait         2.924206     4052584        0
# Morocco        0.000000    35276786   446300
# Nigeria        2.619034   185989640   910770
# Qatar          3.495070     2569804    11610
# Sweden         0.000000     9903122   407310
# India          1.148215  1324171354  2973190

# %%
countries_copy2
# Out:
#              Pop_growth           Pop       Area
# Brazil         0.817556  2.076529e+08  8358140.0
# Switzerland    1.077221  8.372098e+06    39516.0
# Germany        1.193867  8.266768e+07   348900.0
# Denmark        0.834638  1.565725e+08    42262.0
# Spain         -0.008048  4.644396e+07   500210.0
# France         0.407491  6.689611e+07   547557.0
# Japan         -0.115284  1.269945e+08   364560.0
# Greece        -0.687543  1.074674e+07   128900.0
# Iran           1.148789  8.027743e+07  1628760.0
# Kuwait         2.924206  4.052584e+06  1193427.5
# Morocco        1.142708  3.527679e+07   446300.0
# Nigeria        2.619034  1.859896e+08   910770.0
# Qatar          3.495070  2.569804e+06    11610.0
# Sweden         1.142708  9.903122e+06   407310.0
# India          1.148215  1.324171e+09  2973190.0

# %%
dup_data=pd.read_csv('mydata.csv')

# %%
dup_data
# Out:
#    columns1 columns2 columns3
# 0         1        a        A
# 1         2        a        A
# 2         2        a        A
# 3         3        b        B
# 4         4        b        B
# 5         4        b        B

# %%
dup_data.duplicated()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# 5     True
# dtype: bool

# %%
dup_data.drop_duplicates()
# Out:
#    columns1 columns2 columns3
# 0         1        a        A
# 1         2        a        A
# 3         3        b        B
# 4         4        b        B

# %%
dup_data.drop_duplicates(['columns3'])
# Out:
#    columns1 columns2 columns3
# 0         1        a        A
# 3         3        b        B

# %%
source1=pd.read_csv('my_source1.csv')

# %%
source1
# Out:
#        0  1   2   3   4
# 0  babak  1  13  17  17
# 1   raha  2  14  14  15
# 2   sara  3  17  12  20
# 3   reza  4  12  18  19

# %%
source2=pd.read_csv('my_source2.csv')

# %%
source2
# Out:
#         0  1   2   3
# 0   babak  1  13  17
# 1   baran  2  15  20
# 2    sara  3  14  19
# 3   arash  4  20  19
# 4  mehran  5  15  18
# 5    reza  6  14  12

# %%
source=pd.concat([source1,source2],axis=0,ignore_index=True)

# %%
source
# Out:
#         0  1   2   3     4
# 0   babak  1  13  17  17.0
# 1    raha  2  14  14  15.0
# 2    sara  3  17  12  20.0
# 3    reza  4  12  18  19.0
# 4   babak  1  13  17   NaN
# 5   baran  2  15  20   NaN
# 6    sara  3  14  19   NaN
# 7   arash  4  20  19   NaN
# 8  mehran  5  15  18   NaN
# 9    reza  6  14  12   NaN

# %%
source.drop('4',axis=1,inplace=True)

# %%
source
# Out:
#         0  1   2   3
# 0   babak  1  13  17
# 1    raha  2  14  14
# 2    sara  3  17  12
# 3    reza  4  12  18
# 4   babak  1  13  17
# 5   baran  2  15  20
# 6    sara  3  14  19
# 7   arash  4  20  19
# 8  mehran  5  15  18
# 9    reza  6  14  12

# %%
source.drop_duplicates(inplace=True,ignore_index=True)

# %%
source
# Out:
#         0  1   2   3
# 0   babak  1  13  17
# 1    raha  2  14  14
# 2    sara  3  17  12
# 3    reza  4  12  18
# 4   baran  2  15  20
# 5    sara  3  14  19
# 6   arash  4  20  19
# 7  mehran  5  15  18
# 8    reza  6  14  12

# %%
smartphones=pd.read_csv('smartphones.csv')

# %%
smartphones
# Out:
#                 Name        OS  Capacity  Ram  Weight    Company  inch
# 0         Galaxy S10   Android       128    8   163.0    Samsung   6.2
# 1          Lumia 950  windows         32    3   150.0  Microsoft   5.2
# 2        Xpreia 1 ll   Android       256    8   181.0       Sony   6.5
# 3          iphone 7        ios       128    2   138.0      Apple   4.7
# 4            U Ultra   Android        64    4   170.0        HTC   5.7
# 5          Galaxy S5   Android        16    2   145.0    Samsung   5.1
# 6  iphone 11 pro max       ios       256    4   226.0      Apple   6.5
# 7            Moto G5   Android        16    3   144.5   Motorola   5.0
# 8             Pixel    Android       128    4   143.0     Google   5.0

# %%
smartphones.describe()
# Out:
#          Capacity       Ram      Weight      inch
# count    9.000000  9.000000    9.000000  9.000000
# mean   113.777778  4.222222  162.277778  5.544444
# std     93.104481  2.279132   27.833333  0.698411
# min     16.000000  2.000000  138.000000  4.700000
# 25%     32.000000  3.000000  144.500000  5.000000
# 50%    128.000000  4.000000  150.000000  5.200000
# 75%    128.000000  4.000000  170.000000  6.200000
# max    256.000000  8.000000  226.000000  6.500000

# %%
smartphones.dtypes
# Out:
# Name         object
# OS           object
# Capacity      int64
# Ram           int64
# Weight      float64
# Company      object
# inch        float64
# dtype: object

# %%
smartphones.OS.value_counts()
# Out:
# OS
# Android     6
# ios         2
# windows     1
# Name: count, dtype: int64

# %%
smartphones.Company.value_counts()
# Out:
# Company
# Samsung      2
# Apple        2
# Microsoft    1
# Sony         1
# HTC          1
# Motorola     1
# Google       1
# Name: count, dtype: int64

# %%
cat_os=smartphones.groupby(smartphones.OS)

# %%
cat_os

# %%
cat_os.mean(numeric_only=True)
# Out:
#             Capacity       Ram  Weight      inch
# OS
# Android   101.333333  4.833333  157.75  5.583333
# ios       192.000000  3.000000  182.00  5.600000
# windows    32.000000  3.000000  150.00  5.200000

# %%
cat_os.median(numeric_only=True)
# Out:
#           Capacity  Ram  Weight  inch
# OS
# Android       96.0  4.0   154.0   5.4
# ios          192.0  3.0   182.0   5.6
# windows       32.0  3.0   150.0   5.2

# %%
cat_os.boxplot(figsize=(12,8))
# Out:
# Android          Axes(0.1,0.559091;0.363636x0.340909)
# ios         Axes(0.536364,0.559091;0.363636x0.340909)
# windows              Axes(0.1,0.15;0.363636x0.340909)
# dtype: object

# %%
cat_os.max()
# Out:
#                  Name  Capacity  Ram  Weight    Company  inch
# OS
# Android   Xpreia 1 ll       256    8   181.0       Sony   6.5
# ios         iphone 7        256    4   226.0      Apple   6.5
# windows     Lumia 950        32    3   150.0  Microsoft   5.2

# %%
cat_os.min()
# Out:
#                        Name  Capacity  Ram  Weight    Company  inch
# OS
# Android          Galaxy S10        16    2   143.0     Google   5.0
# ios       iphone 11 pro max       128    2   138.0      Apple   4.7
# windows           Lumia 950        32    3   150.0  Microsoft   5.2

# %%
pd.crosstab(smartphones.OS,smartphones.Ram)
# Out:
# Ram       2  3  4  8
# OS
# Android   1  1  2  2
# ios       1  0  1  0
# windows   0  1  0  0

# %%
pd.pivot_table(data=smartphones,index='Name',columns='Company',values='Ram')
# Out:
# Company            Apple  Google  HTC  Microsoft  Motorola  Samsung  Sony
# Name
# Galaxy S10           NaN     NaN  NaN        NaN       NaN      8.0   NaN
# Galaxy S5            NaN     NaN  NaN        NaN       NaN      2.0   NaN
# Lumia 950            NaN     NaN  NaN        3.0       NaN      NaN   NaN
# Moto G5              NaN     NaN  NaN        NaN       3.0      NaN   NaN
# Pixel                NaN     4.0  NaN        NaN       NaN      NaN   NaN
# U Ultra              NaN     NaN  4.0        NaN       NaN      NaN   NaN
# Xpreia 1 ll          NaN     NaN  NaN        NaN       NaN      NaN   8.0
# iphone 11 pro max    4.0     NaN  NaN        NaN       NaN      NaN   NaN
# iphone 7             2.0     NaN  NaN        NaN       NaN      NaN   NaN

# %%
smartphones.rename(index=smartphones.Name,inplace=True)

# %%
smartphones
# Out:
#                                 Name        OS  Capacity  Ram  Weight  \
# Galaxy S10                Galaxy S10   Android       128    8   163.0
# Lumia 950                  Lumia 950  windows         32    3   150.0
# Xpreia 1 ll              Xpreia 1 ll   Android       256    8   181.0
# iphone 7                   iphone 7        ios       128    2   138.0
# U Ultra                      U Ultra   Android        64    4   170.0
# Galaxy S5                  Galaxy S5   Android        16    2   145.0
# iphone 11 pro max  iphone 11 pro max       ios       256    4   226.0
# Moto G5                      Moto G5   Android        16    3   144.5
# Pixel                         Pixel    Android       128    4   143.0
#
#                      Company  inch
# Galaxy S10           Samsung   6.2
# Lumia 950          Microsoft   5.2
# Xpreia 1 ll             Sony   6.5
# iphone 7               Apple   4.7
# U Ultra                  HTC   5.7
# Galaxy S5            Samsung   5.1
# ...

# %%
smartphones.drop(['Name','Company'],inplace=True,axis=1)

# %%
smartphones
# Out:
#                          OS  Capacity  Ram  Weight  inch
# Galaxy S10          Android       128    8   163.0   6.2
# Lumia 950          windows         32    3   150.0   5.2
# Xpreia 1 ll         Android       256    8   181.0   6.5
# iphone 7                ios       128    2   138.0   4.7
# U Ultra             Android        64    4   170.0   5.7
# Galaxy S5           Android        16    2   145.0   5.1
# iphone 11 pro max       ios       256    4   226.0   6.5
# Moto G5             Android        16    3   144.5   5.0
# Pixel               Android       128    4   143.0   5.0

# %%
smartphones_dummy=pd.get_dummies(smartphones)

# %%
smartphones_dummy
# Out:
#                    Capacity  Ram  Weight  inch  OS_Android  OS_ios  \
# Galaxy S10              128    8   163.0   6.2        True   False
# Lumia 950                32    3   150.0   5.2       False   False
# Xpreia 1 ll             256    8   181.0   6.5        True   False
# iphone 7                128    2   138.0   4.7       False    True
# U Ultra                  64    4   170.0   5.7        True   False
# Galaxy S5                16    2   145.0   5.1        True   False
# iphone 11 pro max       256    4   226.0   6.5       False    True
# Moto G5                  16    3   144.5   5.0        True   False
# Pixel                   128    4   143.0   5.0        True   False
#
#                    OS_windows
# Galaxy S10               False
# Lumia 950                 True
# Xpreia 1 ll              False
# iphone 7                 False
# U Ultra                  False
# Galaxy S5                False
# iphone 11 pro max        False
# Moto G5                  False
# ...

# %%
smartphones_dummy.columns
# Out:
# Index(['Capacity', 'Ram', 'Weight', 'inch', 'OS_Android', 'OS_ios',
#        'OS_windows '],
#       dtype='object')

# %%
smartphones_dummy.describe()
# Out:
#          Capacity       Ram      Weight      inch
# count    9.000000  9.000000    9.000000  9.000000
# mean   113.777778  4.222222  162.277778  5.544444
# std     93.104481  2.279132   27.833333  0.698411
# min     16.000000  2.000000  138.000000  4.700000
# 25%     32.000000  3.000000  144.500000  5.000000
# 50%    128.000000  4.000000  150.000000  5.200000
# 75%    128.000000  4.000000  170.000000  6.200000
# max    256.000000  8.000000  226.000000  6.500000

# %%
smartphones_dummy[['OS_windows ','OS_ios','OS_Android']]= smartphones_dummy[['OS_windows ','OS_ios','OS_Android']].astype(int )

# %%
smartphones_dummy
# Out:
#                    Capacity  Ram  Weight  inch  OS_Android  OS_ios  \
# Galaxy S10              128    8   163.0   6.2           1       0
# Lumia 950                32    3   150.0   5.2           0       0
# Xpreia 1 ll             256    8   181.0   6.5           1       0
# iphone 7                128    2   138.0   4.7           0       1
# U Ultra                  64    4   170.0   5.7           1       0
# Galaxy S5                16    2   145.0   5.1           1       0
# iphone 11 pro max       256    4   226.0   6.5           0       1
# Moto G5                  16    3   144.5   5.0           1       0
# Pixel                   128    4   143.0   5.0           1       0
#
#                    OS_windows
# Galaxy S10                   0
# Lumia 950                    1
# Xpreia 1 ll                  0
# iphone 7                     0
# U Ultra                      0
# Galaxy S5                    0
# iphone 11 pro max            0
# Moto G5                      0
# ...

# %%
smartphones_dummy.drop(['OS_windows '],axis=1,inplace=True)

# %%
smartphones_dummy
# Out:
#                    Capacity  Ram  Weight  inch  OS_Android  OS_ios
# Galaxy S10              128    8   163.0   6.2           1       0
# Lumia 950                32    3   150.0   5.2           0       0
# Xpreia 1 ll             256    8   181.0   6.5           1       0
# iphone 7                128    2   138.0   4.7           0       1
# U Ultra                  64    4   170.0   5.7           1       0
# Galaxy S5                16    2   145.0   5.1           1       0
# iphone 11 pro max       256    4   226.0   6.5           0       1
# Moto G5                  16    3   144.5   5.0           1       0
# Pixel                   128    4   143.0   5.0           1       0

# %%
smartphones_dummy.describe()
# Out:
#          Capacity       Ram      Weight      inch  OS_Android    OS_ios
# count    9.000000  9.000000    9.000000  9.000000    9.000000  9.000000
# mean   113.777778  4.222222  162.277778  5.544444    0.666667  0.222222
# std     93.104481  2.279132   27.833333  0.698411    0.500000  0.440959
# min     16.000000  2.000000  138.000000  4.700000    0.000000  0.000000
# 25%     32.000000  3.000000  144.500000  5.000000    0.000000  0.000000
# 50%    128.000000  4.000000  150.000000  5.200000    1.000000  0.000000
# 75%    128.000000  4.000000  170.000000  6.200000    1.000000  0.000000
# max    256.000000  8.000000  226.000000  6.500000    1.000000  1.000000

# %%
from sklearn.preprocessing import scale

# %%
smartphones_scale=scale(smartphones_dummy)

# %%
smartphones_scale
# Out:
# array([[ 0.16202168,  1.75809815,  0.02752212,  0.99557678,  0.70710678,
#         -0.53452248],
#        [-0.93162467, -0.56879646, -0.46787604, -0.52309966, -1.41421356,
#         -0.53452248],
#        [ 1.62021682,  1.75809815,  0.71345804,  1.45117971,  0.70710678,
#         -0.53452248],
#        [ 0.16202168, -1.03417538, -0.92516666, -1.28243788, -1.41421356,
#          1.87082869],
#        [-0.56707589, -0.10341754,  0.29427498,  0.23623856,  0.70710678,
#         -0.53452248],
#        [-1.11389906, -1.03417538, -0.6584138 , -0.67496731,  0.70710678,
#         -0.53452248],
#        [ 1.62021682, -0.10341754,  2.42829784,  1.45117971, -1.41421356,
#          1.87082869],
#        [-1.11389906, -0.56879646, -0.67746757, -0.82683495,  0.70710678,
#         -0.53452248],
#        [ 0.16202168, -0.10341754, -0.7346289 , -0.82683495,  0.70710678,
#         -0.53452248]])

# %%
smartphones_scale=pd.DataFrame(data=smartphones_scale,index=smartphones_dummy.index,columns=smartphones_dummy.columns)

# %%
smartphones_scale
# Out:
#                    Capacity       Ram    Weight      inch  OS_Android  \
# Galaxy S10         0.162022  1.758098  0.027522  0.995577    0.707107
# Lumia 950         -0.931625 -0.568796 -0.467876 -0.523100   -1.414214
# Xpreia 1 ll        1.620217  1.758098  0.713458  1.451180    0.707107
# iphone 7           0.162022 -1.034175 -0.925167 -1.282438   -1.414214
# U Ultra           -0.567076 -0.103418  0.294275  0.236239    0.707107
# Galaxy S5         -1.113899 -1.034175 -0.658414 -0.674967    0.707107
# iphone 11 pro max  1.620217 -0.103418  2.428298  1.451180   -1.414214
# Moto G5           -1.113899 -0.568796 -0.677468 -0.826835    0.707107
# Pixel              0.162022 -0.103418 -0.734629 -0.826835    0.707107
#
#                      OS_ios
# Galaxy S10        -0.534522
# Lumia 950         -0.534522
# Xpreia 1 ll       -0.534522
# iphone 7           1.870829
# U Ultra           -0.534522
# Galaxy S5         -0.534522
# iphone 11 pro max  1.870829
# Moto G5           -0.534522
# ...

# %%
smartphones_scale.describe()
# Out:
#            Capacity           Ram        Weight          inch    OS_Android  \
# count  9.000000e+00  9.000000e+00  9.000000e+00  9.000000e+00  9.000000e+00
# mean   4.009139e-17 -4.934325e-17  2.467162e-16 -1.060880e-15  7.401487e-17
# std    1.060660e+00  1.060660e+00  1.060660e+00  1.060660e+00  1.060660e+00
# min   -1.113899e+00 -1.034175e+00 -9.251667e-01 -1.282438e+00 -1.414214e+00
# 25%   -9.316247e-01 -5.687965e-01 -6.774676e-01 -8.268350e-01 -1.414214e+00
# 50%    1.620217e-01 -1.034175e-01 -4.678760e-01 -5.230997e-01  7.071068e-01
# 75%    1.620217e-01 -1.034175e-01  2.942750e-01  9.955768e-01  7.071068e-01
# max    1.620217e+00  1.758098e+00  2.428298e+00  1.451180e+00  7.071068e-01
#
#              OS_ios
# count  9.000000e+00
# mean   3.700743e-17
# std    1.060660e+00
# min   -5.345225e-01
# 25%   -5.345225e-01
# 50%   -5.345225e-01
# 75%   -5.345225e-01
# max    1.870829e+00

# %%
from sklearn.preprocessing import normalize

# %%
smartphones_normalize_l1=normalize(smartphones_dummy,norm='l1',axis=0)

# %%
smartphones_normalize_l1=pd.DataFrame(data=smartphones_normalize_l1,index=smartphones_dummy.index,columns=smartphones_dummy.columns)

# %%
smartphones_normalize_l1
# Out:
#                    Capacity       Ram    Weight      inch  OS_Android  OS_ios
# Galaxy S10         0.125000  0.210526  0.111606  0.124248    0.166667     0.0
# Lumia 950          0.031250  0.078947  0.102705  0.104208    0.000000     0.0
# Xpreia 1 ll        0.250000  0.210526  0.123930  0.130261    0.166667     0.0
# iphone 7           0.125000  0.052632  0.094488  0.094188    0.000000     0.5
# U Ultra            0.062500  0.105263  0.116398  0.114228    0.166667     0.0
# Galaxy S5          0.015625  0.052632  0.099281  0.102204    0.166667     0.0
# iphone 11 pro max  0.250000  0.105263  0.154742  0.130261    0.000000     0.5
# Moto G5            0.015625  0.078947  0.098939  0.100200    0.166667     0.0
# Pixel              0.125000  0.105263  0.097912  0.100200    0.166667     0.0

# %%
smartphones_normalize_l2=normalize(smartphones_dummy,norm='l2',axis=0)

# %%
smartphones_normalize_l2=pd.DataFrame(data=smartphones_normalize_l2,index=smartphones_dummy.index,columns=smartphones_dummy.columns)

# %%
smartphones_normalize_l2
# Out:
#                    Capacity       Ram    Weight      inch  OS_Android  \
# Galaxy S10         0.296908  0.562878  0.330523  0.370144    0.408248
# Lumia 950          0.074227  0.211079  0.304163  0.310444    0.000000
# Xpreia 1 ll        0.593816  0.562878  0.367023  0.388055    0.408248
# iphone 7           0.296908  0.140720  0.279830  0.280593    0.000000
# U Ultra            0.148454  0.281439  0.344718  0.340294    0.408248
# Galaxy S5          0.037113  0.140720  0.294024  0.304474    0.408248
# iphone 11 pro max  0.593816  0.281439  0.458272  0.388055    0.000000
# Moto G5            0.037113  0.211079  0.293010  0.298503    0.408248
# Pixel              0.296908  0.281439  0.289968  0.298503    0.408248
#
#                      OS_ios
# Galaxy S10         0.000000
# Lumia 950          0.000000
# Xpreia 1 ll        0.000000
# iphone 7           0.707107
# U Ultra            0.000000
# Galaxy S5          0.000000
# iphone 11 pro max  0.707107
# Moto G5            0.000000
# ...

# %%
smartphones_normalize_l1.describe()
# Out:
#        Capacity       Ram    Weight      inch  OS_Android    OS_ios
# count  9.000000  9.000000  9.000000  9.000000    9.000000  9.000000
# mean   0.111111  0.111111  0.111111  0.111111    0.111111  0.111111
# std    0.090922  0.059977  0.019057  0.013996    0.083333  0.220479
# min    0.015625  0.052632  0.094488  0.094188    0.000000  0.000000
# 25%    0.031250  0.078947  0.098939  0.100200    0.000000  0.000000
# 50%    0.125000  0.105263  0.102705  0.104208    0.166667  0.000000
# 75%    0.125000  0.105263  0.116398  0.124248    0.166667  0.000000
# max    0.250000  0.210526  0.154742  0.130261    0.166667  0.500000

# %%
smartphones_normalize_l2.describe()
# Out:
#        Capacity       Ram    Weight      inch  OS_Android    OS_ios
# count  9.000000  9.000000  9.000000  9.000000    9.000000  9.000000
# mean   0.263918  0.297075  0.329059  0.331007    0.272166  0.157135
# std    0.215964  0.160359  0.056439  0.041696    0.204124  0.311805
# min    0.037113  0.140720  0.279830  0.280593    0.000000  0.000000
# 25%    0.074227  0.211079  0.293010  0.298503    0.000000  0.000000
# 50%    0.296908  0.281439  0.304163  0.310444    0.408248  0.000000
# 75%    0.296908  0.281439  0.344718  0.370144    0.408248  0.000000
# max    0.593816  0.562878  0.458272  0.388055    0.408248  0.707107

# %%
from sklearn.preprocessing import minmax_scale

# %%
smartphones_minmax_scale=minmax_scale(smartphones_dummy,feature_range=(0,1),axis=0)

# %%
smartphones_minmax_scale=pd.DataFrame(data=smartphones_minmax_scale,index=smartphones_dummy.index,columns=smartphones_dummy.columns)

# %%
smartphones_minmax_scale
# Out:
#                    Capacity       Ram    Weight      inch  OS_Android  OS_ios
# Galaxy S10         0.466667  1.000000  0.284091  0.833333         1.0     0.0
# Lumia 950          0.066667  0.166667  0.136364  0.277778         0.0     0.0
# Xpreia 1 ll        1.000000  1.000000  0.488636  1.000000         1.0     0.0
# iphone 7           0.466667  0.000000  0.000000  0.000000         0.0     1.0
# U Ultra            0.200000  0.333333  0.363636  0.555556         1.0     0.0
# Galaxy S5          0.000000  0.000000  0.079545  0.222222         1.0     0.0
# iphone 11 pro max  1.000000  0.333333  1.000000  1.000000         0.0     1.0
# Moto G5            0.000000  0.166667  0.073864  0.166667         1.0     0.0
# Pixel              0.466667  0.333333  0.056818  0.166667         1.0     0.0

# %%
smartphones_minmax_scale.describe()
# Out:
#        Capacity       Ram    Weight      inch  OS_Android    OS_ios
# count  9.000000  9.000000  9.000000  9.000000    9.000000  9.000000
# mean   0.407407  0.370370  0.275884  0.469136    0.666667  0.222222
# std    0.387935  0.379855  0.316288  0.388006    0.500000  0.440959
# min    0.000000  0.000000  0.000000  0.000000    0.000000  0.000000
# 25%    0.066667  0.166667  0.073864  0.166667    0.000000  0.000000
# 50%    0.466667  0.333333  0.136364  0.277778    1.000000  0.000000
# 75%    0.466667  0.333333  0.363636  0.833333    1.000000  0.000000
# max    1.000000  1.000000  1.000000  1.000000    1.000000  1.000000

# %%
smartphones_normalize_l1
# Out:
#                    Capacity       Ram    Weight      inch  OS_Android  OS_ios
# Galaxy S10         0.125000  0.210526  0.111606  0.124248    0.166667     0.0
# Lumia 950          0.031250  0.078947  0.102705  0.104208    0.000000     0.0
# Xpreia 1 ll        0.250000  0.210526  0.123930  0.130261    0.166667     0.0
# iphone 7           0.125000  0.052632  0.094488  0.094188    0.000000     0.5
# U Ultra            0.062500  0.105263  0.116398  0.114228    0.166667     0.0
# Galaxy S5          0.015625  0.052632  0.099281  0.102204    0.166667     0.0
# iphone 11 pro max  0.250000  0.105263  0.154742  0.130261    0.000000     0.5
# Moto G5            0.015625  0.078947  0.098939  0.100200    0.166667     0.0
# Pixel              0.125000  0.105263  0.097912  0.100200    0.166667     0.0

# %%
plt.figure(figsize=(12,6))
plt.plot(smartphones_normalize_l1,c=smartphones_normalize_l1.in)

# %%
outlier_data=pd.DataFrame(np.array([-8,5,-0,80,12,2,3,1]))

# %%
outlier_data
# Out:
#     0
# 0  -8
# 1   5
# 2   0
# 3  80
# 4  12
# 5   2
# 6   3
# 7   1

# %%
outlier_data.sort_values(by=0,inplace=True)

# %%
outlier_data
# Out:
#     0
# 0  -8
# 2   0
# 7   1
# 5   2
# 6   3
# 1   5
# 4  12
# 3  80

# %%
outlier_data.boxplot()
# Out:
# <Axes: >

# %%
outlier_data.max()
# Out:
# 0    80
# dtype: int64

# %%
outlier_data.median()
# Out:
# 0    2.5
# dtype: float64

# %%
outlier_data.quantile(.50000)
# Out:
# 0    2.5
# Name: 0.5, dtype: float64
